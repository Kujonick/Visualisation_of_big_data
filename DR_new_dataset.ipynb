# %%
#%pip install bertopic

# %%
# %pip install pandas
import pandas as pd
import numpy as np
from transformers import pipeline
import torch
from tqdm import tqdm
# Out:
# 2025-06-26 12:46:10.728309: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-26 12:46:10.864145: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-06-26 12:46:10.864161: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-06-26 12:46:10.887749: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-26 12:46:11.582511: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2025-06-26 12:46:11.582580: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2025-06-26 12:46:11.582587: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.10

# %%
df = pd.read_parquet("refined2.parquet")

# %%
df
# Out:
#                      date                                              tweet  \
# 0     2021-06-20 05:26:01  What can be done?  - Never blindly trust an ab...
# 1     2021-06-20 04:46:01  "We need a paradigm shift from model-centric t...
# 2     2021-06-20 04:30:00  Using high-resolution satellite data and compu...
# 3     2021-06-20 04:19:01  .@Stephenson_Data shares four steps that will ...
# 4     2021-06-20 02:40:01  "Curricula is inherently brittle in a world wh...
# ...                   ...                                                ...
# 33585 2010-01-06 06:13:47  Need data.gov.sg now! RT @jranck: Chart Wars: ...
# 33586 2010-01-06 03:24:09  Great presentation by @alexlundry: Chart Wars:...
# 33587 2010-01-06 00:29:44  RT @briandevine: u should also check out the d...
# 33588 2010-01-05 19:45:15  New Data Visualization - Application performan...
# 33589 2010-01-04 13:45:57  Good post about data visualization's importanc...
#
#        topic  field
# 0         15      0
# 1         15      0
# 2         15      0
# 3         15      0
# 4         15      0
# ...      ...    ...
# 33585     15      2
# 33586     15      2
# 33587     15      2
# 33588     15      2
# 33589     15      2
#
# [314092 rows x 4 columns]

# %%
df2 = pd.read_csv('data-science-tweets/tweets/data_visualization.csv', usecols=['date', 'time', 'tweet'])

# %%
df2.loc[:,'date'] = pd.to_datetime(df2.date.astype(str)+' '+df2.time.astype(str))

# %%
df2 = df2.drop(columns=['time'])
df2
# Out:
#                       date                                              tweet
# 0      2021-06-20 01:10:03  Take your storytelling to the next level using...
# 1      2021-06-19 22:17:46  Choosing Fonts for Your Data Visualization | b...
# 2      2021-06-19 08:21:55  This data visualization shows where our greate...
# 3      2021-06-18 23:29:21  Looking for examples of stellar charts made so...
# 4      2021-06-18 23:05:03  With #WISQARS Data Visualization, you can disp...
# ...                    ...                                                ...
# 33585  2010-01-06 06:13:47  Need data.gov.sg now! RT @jranck: Chart Wars: ...
# 33586  2010-01-06 03:24:09  Great presentation by @alexlundry: Chart Wars:...
# 33587  2010-01-06 00:29:44  RT @briandevine: u should also check out the d...
# 33588  2010-01-05 19:45:15  New Data Visualization - Application performan...
# 33589  2010-01-04 13:45:57  Good post about data visualization's importanc...
#
# [33590 rows x 2 columns]

# %%
df.to_parquet('refined2.parquet')

# %%
from transformers import AutoModelForSequenceClassification, TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import expit

    
MODEL = f"cardiffnlp/tweet-topic-base-multilingual"
tokenizer = AutoTokenizer.from_pretrained(MODEL)

# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
class_mapping = model.config.id2label

text = "Israeli drone strikes"
tokens = tokenizer(text, return_tensors='pt')
output = model(**tokens)

scores = output[0][0].detach().numpy()
scores = expit(scores)
predictions = (scores >= 0.5) * 1

# %%
inverse_class_mapping = {val: key for key, val in class_mapping.items()}
inverse_class_mapping
# Out:
# {'arts_&_culture': 0,
#  'business_&_entrepreneurs': 1,
#  'celebrity_&_pop_culture': 2,
#  'diaries_&_daily_life': 3,
#  'family': 4,
#  'fashion_&_style': 5,
#  'film_tv_&_video': 6,
#  'fitness_&_health': 7,
#  'food_&_dining': 8,
#  'gaming': 9,
#  'learning_&_educational': 10,
#  'music': 11,
#  'news_&_social_concern': 12,
#  'other_hobbies': 13,
#  'relationships': 14,
#  'science_&_technology': 15,
#  'sports': 16,
#  'travel_&_adventure': 17,
#  'youth_&_student_life': 18}

# %%
fe_pipeline = pipeline(
    task="text-classification",
    model=MODEL,
    torch_dtype=torch.float16,
    device=0
)

# %%
output = [inverse_class_mapping[fe_pipeline(t)[0]['label']] for t in df2['tweet']]
print(len(output))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 output = [inverse_class_mapping[fe_pipeline(t)[0]['label']] for t in df2['tweet']]
#       2 print(len(output))
#
# NameError: name 'df2' is not defined

# %%
df2['topic'] = output
#df1.to_parquet('refined2.parquet')

# %%
df2['field'] = 2

# %%
df2
# Out:
#                       date                                              tweet  \
# 0      2021-06-20 01:10:03  Take your storytelling to the next level using...
# 1      2021-06-19 22:17:46  Choosing Fonts for Your Data Visualization | b...
# 2      2021-06-19 08:21:55  This data visualization shows where our greate...
# 3      2021-06-18 23:29:21  Looking for examples of stellar charts made so...
# 4      2021-06-18 23:05:03  With #WISQARS Data Visualization, you can disp...
# ...                    ...                                                ...
# 33585  2010-01-06 06:13:47  Need data.gov.sg now! RT @jranck: Chart Wars: ...
# 33586  2010-01-06 03:24:09  Great presentation by @alexlundry: Chart Wars:...
# 33587  2010-01-06 00:29:44  RT @briandevine: u should also check out the d...
# 33588  2010-01-05 19:45:15  New Data Visualization - Application performan...
# 33589  2010-01-04 13:45:57  Good post about data visualization's importanc...
#
#        topic  field
# 0         10      2
# 1         15      2
# 2         15      2
# 3         15      2
# 4         16      2
# ...      ...    ...
# 33585     15      2
# 33586     15      2
# 33587     15      2
# 33588     15      2
# 33589     15      2
#
# [33590 rows x 4 columns]

# %%
df = pd.concat([df,df1,df2],axis=0)

# %%
df['field'].value_counts()
# Out:
# field
# 0    241386
# 1     39116
# 2     33590
# Name: count, dtype: int64

# %%
df
# Out:
#                       date                                              tweet  \
# 0      2021-06-20 05:26:01  What can be done?  - Never blindly trust an ab...
# 1      2021-06-20 04:46:01  "We need a paradigm shift from model-centric t...
# 2      2021-06-20 04:30:00  Using high-resolution satellite data and compu...
# 3      2021-06-20 04:19:01  .@Stephenson_Data shares four steps that will ...
# 4      2021-06-20 02:40:01  "Curricula is inherently brittle in a world wh...
# ...                    ...                                                ...
# 33585  2010-01-06 06:13:47  Need data.gov.sg now! RT @jranck: Chart Wars: ...
# 33586  2010-01-06 03:24:09  Great presentation by @alexlundry: Chart Wars:...
# 33587  2010-01-06 00:29:44  RT @briandevine: u should also check out the d...
# 33588  2010-01-05 19:45:15  New Data Visualization - Application performan...
# 33589  2010-01-04 13:45:57  Good post about data visualization's importanc...
#
#        topic  field
# 0         15      0
# 1         15      0
# 2         15      0
# 3         15      0
# 4         15      0
# ...      ...    ...
# 33585     15      2
# 33586     15      2
# 33587     15      2
# 33588     15      2
# 33589     15      2
#
# [314092 rows x 4 columns]

# %%
min([len(i) for i in df.iloc[:900]['tweet']])
# Out:
# 42

# %%
df.iloc[400:450]['tweet'].to_list()
# Out:
# ['#AlmaBetter aims to train 25,000 data science aspirants by March next year to make them employment-ready. It has allocated a Rs 2 crore fund to encourage more students to take up the subject.  @AlmaBetter   https://t.co/Tm74CxywL0',
#  "Confirmed: High proportion of women, black and disabled students enrolled on AI &amp; data science courses!  Now: We're seeking companies who want to recruit students for paid placements and help them gain experience + contribute to the sector.  Find out more:  https://t.co/XcZbYhQCDI  https://t.co/xGEjkaQ0a5",
#  'Quantum physics both underlies our everyday lives and is a vast and mysterious realm. By comparing theories with experimental data, researchers @Harvard are working to map out the laws that govern the quantum realm:  https://t.co/SmV42BxCcO  https://t.co/59tQj2I0xG',
#  ".@CIOdive found that 1 in 5 #data professionals say the infrastructure and systems in place are unable to scale accordingly in response to increased data volume processing needs. What's the solution?  https://t.co/vVWzy8WbUU",
#  'Tired of the same old statistical analysis tools? Learn the multiparadigm approach to #DataScience at our Data Science Boot Camp by incorporating #AI and automation to create a human-data interface or computational essay from a dataset of your choice.  https://t.co/rHYIOhIDsY  https://t.co/6Win5SHeSr',
#  "Science &amp; medicine aren't immune to the danger of reducing a complex phenomenon to an overly simplistic cutoff point rule that does harm. We have @linseymarr, @jljcolorado, &amp; Yuguo Li to thank for challenging the 5-micron aerosol dogma that led to poor early COVID-19 guidance.",
#  'The CIO’s Guide to Building a Rockstar Data Science and AI Team  https://t.co/heXmWRwt4F via @eWEEK',
#  'Thank you @RepAndyHarrisMD for asking the governor to reverse 2-dose vaccine mandates for students. The requirement ignores the science of natural immunity &amp; ignores the data on the power of the 1st dose to protect kids without the cardiac risks of the 2nd  https://t.co/UjRiPsBiD9',
#  'Data Science Masa Depan Indonesia  https://t.co/qYBYNw3LLf',
#  'Dataiku was recognized by @SnowflakeDB as Data Science Partner of the Year at Snowflake Summit. As a key part of the Snowflake Data Cloud ecosystem, Dataiku makes it even easier to harness the value of advanced analytics and AI-driven applications.|  https://t.co/wmsoimrdWF  https://t.co/eX2ZtqAgKK',
#  'Bring together #machinelearning &amp; #deeplearning in financial trading and bridge the gap between #finance and #datascience with a systematic method for structuring, analyzing, and optimizing an investment portfolio and its underlying asset classes.  https://t.co/vv9NocuvZv  https://t.co/oYDc2YtwsR',
#  'NaN, None and Experimental NA by Deepak Tunuguntla   https://t.co/JrsBm0bK7u',
#  'Following up that 🤯 demo with awesome talks across 5 different tracks: #Neo4j, Visualization, Apps &amp; APIs, Data Science, and Best Practice.  Keep watching:  https://t.co/0jSWQHDXEx',
#  'We used #machinelearning and #deeplearning techniques to explore behaviour and well-being changes during the #COVID19 pandemic. More in our latest blog post 👇  https://t.co/58Z1b7eEyQ',
#  '.@SASsoftware debuts new brand campaign "Curiosity Forever":  https://t.co/cbp0IVa0jK ———— #SASGF #SASVisionary #DataLiteracy #DataFluency #BigData #Analytics #AnalyticThinking #DataScience #AI #MachineLearning #DataLeadership  https://t.co/n2iHNJgWAw',
#  '#TTP Ep. 137—Buckle up for this week’s fast-paced podcast discussion with Lance James, CEO of Unit 221B. Hear about his discovery of the Zeus #malware, the emergence of psyber (where data science, psychology and cyber intersect) and more:  https://t.co/RkWmdva7wo   #cybersecurity  https://t.co/Q8nWL4SqVj',
#  "@camillevleonard @tamaramunzner @IsabelMeirelles @storywithdata @evergreendata @sxywu @NadiehBremer @LacePadilla @JessicaHullman @ChristiansenJen @AlliTorban Tamara for sci vis. Cole &amp; Stephanie for business viz. Jen for popular science graphics. Jessica and Lace (papers) if you are interested in uncertainty and its communication. Nadieh/Shirley for data+art. Isabel's for historical perspective. Ali and @lisacrost for blogs/podcast",
#  'Join our webinar on June 29 to find out how industry leaders apply CETSA® by Pelago Bioscience to gain clarity in complexity earlier in the #drugdiscovery journey by generating physiologically relevant target engagement data. Register here:  https://t.co/lVoI8L76x9 #LifeSciences  https://t.co/LXQT1lC81x',
#  'How is #JuniperNetworks applying AI and data science tools? 🩺 Global Healthcare Practice Lead, Matt Roberts, highlights the effectiveness of AI-driven networks for patients and healthcare providers at our EMEA Healthcare #JuniperSummit.  Join the session:  https://t.co/szCNUPIPOx  https://t.co/uZ0qkXOJS2',
#  'Reproducible Data Analysis in Python without Coding by Tobias Krabel   https://t.co/ZggSkdzd3R',
#  'Some of the exciting projects #moringaschool graduates have worked on.   Which other #datascience projects are you working on or recommend learners to jump on?   #datascientists #python #rstats #rpogramming #machinelearning  https://t.co/qJDYNUpRJ2',
#  "America's #COVID19 evidence-based response, leadership that respects data, scientists, and funds science have led a turnaround in the country. India needs a course correction too, @iimb_official writes  https://t.co/k5y9YrkXEz",
#  '⭐️ NEW analysis shows big boost in numbers of women enrolling on AI and data science courses!  🎓 The courses, based at 28 universities across England, aim to respond to a skills shortage and a lack of diversity in the UK tech sector.  #TechPriorities   👉  https://t.co/SsNhio0rZy  https://t.co/6cPbYrIQeN',
#  'Graham Stringer, who questioned Dominic Cummings and Matt Hancock at the science committee last month, says the health secretary cherry-picked the data he used, telling Times Radio his evidence "substantiates a lot of Dominic Cummings\' criticism of him."  @AasmahMir | @StigAbell  https://t.co/IdZnbzAeol',
#  'Build a multi-class classification neural network in R in fifty lines of code by Theviyanthan Krishnamohan   https://t.co/5rBiuFcLrk',
#  'Last Day to register for our #MachineLearning #DataScience Shoe Image Classifier Challenge as part of our #EdgeNet program.  @AlefNYC #Topcoder Register here: [$1400/$700/$350] - EdgeNet - Shoe Image Classifier Challenge  https://t.co/aHl6M4DqeI',
#  'Can We Study Snowpack with Satellites? by Will Norris   https://t.co/5JJjvqHqsj',
#  'New @TDWI Research Report Explores Drivers, Challenges, and Opportunities for Unified #Data Warehouses and #DataLakes  via\xa0@IntradoDigital #datalake #dataengineering #datascience #datawarehouse #cloud  https://t.co/RfRzL0OF6B',
#  'Theme: Strengthening the Contribution of Data Science and Official Statistics to the Society in the Disruption Era  https://t.co/afkVGEAjpS',
#  'What is the role of data science and official statistics in the disruption era and how we can develop new innovation and statistical approaches using modern data sources?   Let’s get to know more about this in ICDSOS 2021!  https://t.co/WSbb1qpHVI',
#  'The 1st International Conference on Data Science and Official Statistics (ICDSOS) 2021   In the current disruption era, data has become undoubtedly important as a basis for planning and policy-making in various fields of daily life such as economy, health, education, etc.  https://t.co/WSrkJsEqLn',
#  '@edinburghcoll has launched a fully funded Data Science course designed to equip attendees with vital &amp; in-demand Data Science skills.   Upon successful completion, attendees will also gain a recognised SCQF level 4 qualification.  Find out more here &gt;  https://t.co/hQfDny7rKl',
#  'People-powered Science! 👩\u200d🔬  Did you know that #Taiwan has some of the strongest and longest running #CitizenScience projects for birds in Asia? 🐦  This data is collected by local people and shared with the world! 🌏  Learn more here 🔽🔽🔽',
#  '(1/2)💻📊 Data is the new oil and data mining is the way forward for a better future of technology. The MS-Data Science program offered at the #IBAKarachi amalgamates the different aspects of data-analytics and statistics to find technology-driven solutions for emerging problems.  https://t.co/QrYMhzdEaL',
#  '▪️November 2020: Wrong SAGE modelling data used to justify the restrictions.   ▪️June 2021: Wrong SAGE modelling data used to justify the restrictions.   And yet we are told to follow the science?    https://t.co/DGRcRK9i6b',
#  'Trainable Macroscopic Traffic Modeling using Stochastic Matrices by Alim Toprak Firat  https://t.co/82xHmEhN1D',
#  "Quel est le point commun entre les admissions post bac et Youtube ? &gt;&gt; la #datascience &gt; Étudiants, découvrez ces métiers, les études et débouchés. &gt; Professionnels, découvrez les réflexions éthiques liées à ce secteur en @Occitanie  +d'infos :  https://t.co/SYEjECNQJu  https://t.co/uAfdg7sMWg",
#  'Predictions of how many people might die this summer have been downgraded after new data on vaccinations.  But @whippletom, science editor for The Times, says he does not think this changes the decision to delay "Freedom Day" in England.  @AasmahMir | @StigAbell  https://t.co/URkcKzFQN4',
#  "America's #COVID19 evidence-based response, leadership that respects data, scientists, and funds science have led a turnaround in the country. India needs a course correction too, @iimb_official writes  https://t.co/k5y9Yr3mN1",
#  'Explainable Graph Neural Networks by @RemyLau3  https://t.co/ZWrraQb9Fz',
#  'Join elite #IoT Industry Leaders at the @IoTSlam Live 2021 event — learn how they are transforming their industries:  https://t.co/L3ehy4BJB5 ———— #IoTPL #IIoT #IoTCommunity #AI #Edge #EdgeAI #5G #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing @IoTCommunity  https://t.co/v7wkfLnnGj',
#  '@ucl health data scientist, cat-lover &amp; proudly #LGBTSTEM  Our Newton International Fellow Dr @mehrdad_mizani shares his #MedSciLife   https://t.co/xIDXLMvkY8  🇬🇧🇹🇷🇮🇷  https://t.co/7pZ0xyrZf2',
#  "Here's a quick reminder that our webinar about Data-as-an-Asset is starting in 30 minutes at 10.00CET. Register below to get access. #datamanagement #datascience #dataanalytics #analytics #data #webinar  https://t.co/lz73syOaSR",
#  '🗣️ Senior Marketing Executive Total Performance Data TPD is a London-based sports technology firm, working at the cutting edge of sports science &amp; data technology for a global customer base.  More Info: ➡️  https://t.co/F7LOA68X8P  #RacingJobs #TeamRacing #LiveJobs 🐎  https://t.co/dloN5fbCLE',
#  "COVID-19 has accelerated data-driven innovation across the globe, with AI and data science at the forefront of addressing human disease and health.  Read @businesslondon &amp; @MedCityHQ's new report on London's strengths as a hub for health &amp; life sciences:\xa0 https://t.co/JxPz8q0X8f  https://t.co/b3kxUdvbq3",
#  'Release of “BIOTECH-PRIDE (Promotion of Research and Innovation through Data Exchange) Guidelines By Union Minister for Science &amp; Technology, Health &amp; Family Welfare and Earth Sciences Dr. Harsh Vardhan.  https://t.co/bLPuO2BOda',
#  'Different Imputation Methods to Handle Missing Data by Supriya Secherla   https://t.co/T3RuijFJxI',
#  "A Global Pandemic in a time of precision tools and big data. Discover how far science has come in a century with Dr. William G. Morrice II June 23rd at 17:00pm (CET) at this years 'Science Against SARS-CoV-2' virtual conference.   https://t.co/2CfTw1dNML #scienceagainstsarscov2  https://t.co/p16gnzEFg7",
#  'Lerne am 6. Juli anhand eines praktischen Beispielprojekts, wie du dein Data-Science-Projekt von den Anforderungen bis zur Management-Präsentation meisterst. Jetzt Ticket sichern ➡  https://t.co/IHCP0tFaZn  #datascience #bigdata  https://t.co/IVQ78xf6Yr',
#  'I have 2 online #DataScience #MachineLearning Modeling Courses. Look here: DS 101:  https://t.co/wUQaGf1JbB DS 102:  https://t.co/3FwcYLAF9q ———— #BigData #AI #DataScientists #PredictiveModeling #Algorithms #DataLiteracy #DataLeadership #PredictiveAnalytics #IoT #IIoT #IoTPL #ODSC  https://t.co/8rgzuRFbn1']

# %%
# Setup pipeline on GPU
fe_pipeline = pipeline(
    task="feature-extraction",
    model="vinai/bertweet-base",
    torch_dtype=torch.float16,
    device=0
)
# Out:
# /home/wladek/.local/lib/python3.8/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
import torch
from tqdm import tqdm
import gc
import numpy as np
import re
texts = df['tweet'].tolist()
batch_size = 32
output_file = "/media/wladek/Wladyslaw/bertweet_embeddings_2.pt"


emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

with open(output_file, "ab") as f:
    for i in tqdm(range(0, len(texts), batch_size)):
        batch = [i for i in texts[i:i + batch_size]]

        # Filter out empty or bad tweets
        batch = [emoji_pattern.sub(r'', text) for text in batch if isinstance(text, str) and text.strip()]
        if not batch:
            continue

        try:
            with torch.no_grad():
                outputs_list = fe_pipeline(batch, padding=True, truncation=True, return_tensors="pt")
                
                embeddings = []
                for j, emb in enumerate(outputs_list):
                    try:
                        emb_tensor = torch.tensor(emb)  # [seq_len, hidden_dim]
                        if emb_tensor.ndim != 3 or emb_tensor.shape[0] < 1:
                            print(f"Skipping bad embedding at index {i + j}, shape={emb_tensor.shape}")
                            continue
                        cls_emb = emb_tensor[0, 0]  # CLS token
                        embeddings.append(cls_emb.detach().cpu())
                    except Exception as inner_e:
                        print(f"Inner error at index {i + j}: {inner_e}")
                        continue

                if not embeddings:
                    continue

                outputs = torch.stack(embeddings).float().cpu()
                f.write(outputs.numpy().tobytes())

        except Exception as e:
            print(f"Error at batch {i}: {e}")
            continue

        # Cleanup
        del outputs_list, outputs, embeddings
        gc.collect()
        torch.cuda.empty_cache()
# Out:
#   0%|                                                  | 0/9816 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# /tmp/ipykernel_21452/2746591588.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   emb_tensor = torch.tensor(emb)  # [seq_len, hidden_dim]
#   0%|                                       | 10/9816 [00:15<4:11:19,  1.54s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   0%|                                       | 13/9816 [00:19<3:50:30,  1.41s/it]../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [64,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [70,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [67,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [72,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [69,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [75,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [83,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49728: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49760: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49792: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49824: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49856: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#  16%|██████                                | 1572/9816 [00:34<01:18, 105.07it/s]
# Error at batch 49888: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49920: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49952: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 49984: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50016: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50048: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50080: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50112: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50144: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50176: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50208: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50240: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50272: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50304: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50336: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50368: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50400: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50432: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50464: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50496: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50528: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50560: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#  16%|██████▎                                | 1591/9816 [00:34<02:57, 46.30it/s]
# Error at batch 50592: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50624: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50656: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50688: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50720: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50752: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50784: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50816: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50848: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Error at batch 50880: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1208, in Pipeline.forward(self, model_inputs, **forward_params)
#    1207 with inference_context():
# -> 1208     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
#    1209     model_outputs = self._forward(model_inputs, **forward_params)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1115, in Pipeline._ensure_tensor_on_device(self, inputs, device)
#    1114 elif isinstance(inputs, UserDict):
# -> 1115     return UserDict({name: self._ensure_tensor_on_device(tensor, device) for name, tensor in inputs.items()})
#    1116 elif isinstance(inputs, list):
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1115, in <dictcomp>(.0)
#    1114 elif isinstance(inputs, UserDict):
# -> 1115     return UserDict({name: self._ensure_tensor_on_device(tensor, device) for name, tensor in inputs.items()})
#    1116 elif isinstance(inputs, list):
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1121, in Pipeline._ensure_tensor_on_device(self, inputs, device)
#    1120 elif isinstance(inputs, torch.Tensor):
# -> 1121     return inputs.to(device)
#    1122 else:
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 29
#      27 try:
#      28     with torch.no_grad():
# ---> 29         outputs_list = fe_pipeline(batch, padding=True, truncation=True, return_tensors="pt")
#      31         embeddings = []
#      32         for j, emb in enumerate(outputs_list):
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/feature_extraction.py:86, in FeatureExtractionPipeline.__call__(self, *args, **kwargs)
#      76 def __call__(self, *args, **kwargs):
#      77     """
#      78     Extract the features of the input(s).
#      79
#    (...)
#      84         A nested list of `float`: The features computed by the model.
#      85     """
# ---> 86     return super().__call__(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1283, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1279 if can_use_iterator:
#    1280     final_iterator = self.get_iterator(
#    1281         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1282     )
# -> 1283     outputs = list(final_iterator)
#    1284     return outputs
#    1285 else:
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1208, in Pipeline.forward(self, model_inputs, **forward_params)
#    1206 inference_context = self.get_inference_context()
#    1207 with inference_context():
# -> 1208     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
#    1209     model_outputs = self._forward(model_inputs, **forward_params)
#    1210     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#
# KeyboardInterrupt:

# %%
import numpy as np
with open("/media/wladek/Wladyslaw/bertweet_embeddings.pt", "rb") as f:
    # header = np.frombuffer(f.read(8), dtype=np.int32)
    # total_embeddings, embedding_dim = header
    data = f.read()
    embeddings = np.frombuffer(data, dtype=np.float32).reshape(1_600_000, 768)

# %%
embeddings.shape
# Out:
# (1600000, 768)

# %%
indices = np.random.choice([i for i in range(1_600_000)], size=16_000, replace=False)
embeddings_train = embeddings[indices]

# %%
embeddings_train.shape
# Out:
# (16000, 768)

# %%
import umap
import numpy as np
import joblib
umap_model = umap.UMAP(
    n_neighbors=5,        # controls local vs global structure
    n_components=3,        # 2D for visualization; use 3 or more if needed
    metric='cosine',       # or 'euclidean'
    n_jobs=-1
).fit(embeddings_train)
result = umap_model.transform(embeddings)
result.dump("umap_result_3d.npy")

# %%
result1 = np.load("umap_result_3d.npy", allow_pickle=True)
result1.shape
# Out:
# (1600000, 3)

# %%
from pacmap import PaCMAP
pacmap_model = PaCMAP(n_components=2,
                      n_neighbors=10,
                      MN_ratio=0.5,
                      FP_ratio=2.0,
                     save_tree=True)
pacmap_model.fit(embeddings_train)
result = pacmap_model.transform(embeddings)
result.dump("pacmap_result.npy")

# %%
result1 = np.load("pacmap_result.npy", allow_pickle=True)
result1.shape
# Out:
# (1600000, 2)

# %%
pacmap_model = PaCMAP(n_components=3,
                      n_neighbors=10,
                      MN_ratio=0.5,
                      FP_ratio=2.0,
                     save_tree=True)
pacmap_model.fit(embeddings_train)
result = pacmap_model.transform(embeddings)
result.dump("pacmap_result_3d.npy")
# Out:
# Note: `n_components != 2` have not been thoroughly tested.

# %%
result1 = np.load("pacmap_result_3d.npy", allow_pickle=True)
result1.shape
# Out:
# (1600000, 3)

# %%
from sklearn.decomposition import PCA
pca_model = PCA(n_components=2)
pca_model.fit(embeddings_train)
result = pca_model.transform(embeddings)
result.dump("pca_result.npy")

# %%
pca_model = PCA(n_components=3)
pca_model.fit(embeddings_train)
result = pca_model.transform(embeddings)
result.dump("pca_result_3d.npy")

# %%
from sklearn.decomposition import IncrementalPCA
pca_model = IncrementalPCA(n_components=2, batch_size=1000)
pca_model.fit(embeddings)
result = pca_model.transform(embeddings)
result.dump("incremental_pca_result.npy")

# %%
from sklearn.decomposition import IncrementalPCA
pca_model = IncrementalPCA(n_components=3, batch_size=1000)
pca_model.fit(embeddings)
result = pca_model.transform(embeddings)
result.dump("incremental_pca_result_3d.npy")
